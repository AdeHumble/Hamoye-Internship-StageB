# %% [markdown]
# <div style="text-align: center;">
#     <h1>HAMOYE STAGE B TEST CODE SOLUTIONS</h1>
# </div>

# %% [markdown]
# ## STEP ONE: LOAD NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## STEP TWO: PERFORM DATA PREPROCESSING & EDA
# 1. Load the data
# 2. Preview the data
# 3. Check data type
# 4. Check for missing values
# 5. Check for duplicates
# 6. Explore basic statistics of the data

# %% [markdown]
# ## **1. Load the data**

# %%
data=pd.read_csv("energydata_complete.csv")

# %% [markdown]
# ## **2. Preview the data**

# %%
data.head(5)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %% [markdown]
# ## **3. Check data type**
# - I would like to check if every column in the dataset contains a unique(the same) data types
# - In order not to waste time by using the dtype() on each column, I will prefer to use a for-loop statement to perform this task across the whole dataset columns at once

# %%
# Create an empty DataFrame to store the results
data_type_df = pd.DataFrame(columns=['COLUMN NAMES', 'UNIQUE DATA TYPES'])

# Iterate through columns and store unique data types in the new DataFrame
for column_name in data.columns:
    unique_data_types = data[column_name].apply(type).unique()
    
    #data_type_df = data_type_df.append({'COLUMN NAME': column_name, 'UNIQUE DATA TYPES': unique_data_types}, ignore_index=True)
    data_type_df = pd.concat([data_type_df, pd.DataFrame({'COLUMN NAMES': [column_name], 'UNIQUE DATA TYPES': [unique_data_types]})],ignore_index=True)

# Display the resulting table
print(data_type_df)
# Out:
#    COLUMN NAMES  UNIQUE DATA TYPES
# 0          date    [<class 'str'>]
# 1    Appliances    [<class 'int'>]
# 2        lights    [<class 'int'>]
# 3            T1  [<class 'float'>]
# 4          RH_1  [<class 'float'>]
# 5            T2  [<class 'float'>]
# 6          RH_2  [<class 'float'>]
# 7            T3  [<class 'float'>]
# 8          RH_3  [<class 'float'>]
# 9            T4  [<class 'float'>]
# 10         RH_4  [<class 'float'>]
# 11           T5  [<class 'float'>]
# 12         RH_5  [<class 'float'>]
# 13           T6  [<class 'float'>]
# 14         RH_6  [<class 'float'>]
# 15           T7  [<class 'float'>]
# 16         RH_7  [<class 'float'>]
# 17           T8  [<class 'float'>]
# 18         RH_8  [<class 'float'>]
# 19           T9  [<class 'float'>]
# 20         RH_9  [<class 'float'>]
# 21        T_out  [<class 'float'>]
# 22  Press_mm_hg  [<class 'float'>]
# 23       RH_out  [<class 'float'>]
# 24    Windspeed  [<class 'float'>]
# 25   Visibility  [<class 'float'>]
# ...

# %% [markdown]
# ### **INFERENCE:**
# - Each column contains a unique data type, EXCEPT for date column. Hence, there would be no need to perform type casting

# %%
data['date'] = pd.to_datetime(data['date'])
print(data_type_df)
# Out:
#    COLUMN NAMES  UNIQUE DATA TYPES
# 0          date    [<class 'str'>]
# 1    Appliances    [<class 'int'>]
# 2        lights    [<class 'int'>]
# 3            T1  [<class 'float'>]
# 4          RH_1  [<class 'float'>]
# 5            T2  [<class 'float'>]
# 6          RH_2  [<class 'float'>]
# 7            T3  [<class 'float'>]
# 8          RH_3  [<class 'float'>]
# 9            T4  [<class 'float'>]
# 10         RH_4  [<class 'float'>]
# 11           T5  [<class 'float'>]
# 12         RH_5  [<class 'float'>]
# 13           T6  [<class 'float'>]
# 14         RH_6  [<class 'float'>]
# 15           T7  [<class 'float'>]
# 16         RH_7  [<class 'float'>]
# 17           T8  [<class 'float'>]
# 18         RH_8  [<class 'float'>]
# 19           T9  [<class 'float'>]
# 20         RH_9  [<class 'float'>]
# 21        T_out  [<class 'float'>]
# 22  Press_mm_hg  [<class 'float'>]
# 23       RH_out  [<class 'float'>]
# 24    Windspeed  [<class 'float'>]
# 25   Visibility  [<class 'float'>]
# ...

# %% [markdown]
# ### **INFERENCE:**
# - Now, all the columns in the dataset have the proper data types

# %% [markdown]
# ## **4. Check for missing values**

# %%
data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %% [markdown]
# ### **INFERENCE:**
# - There are no fields with missing values
# - As a check/confirmation of the inference above, the below code line set to prints out rows that contains missing values.
# - However, there was none

# %%
rows_with_missing_values = data.isnull().any(axis=1)
missing_data=data[rows_with_missing_values]
missing_data
# Out:
# Empty DataFrame
# Columns: [date, Appliances, lights, T1, RH_1, T2, RH_2, T3, RH_3, T4, RH_4, T5, RH_5, T6, RH_6, T7, RH_7, T8, RH_8, T9, RH_9, T_out, Press_mm_hg, RH_out, Windspeed, Visibility, Tdewpoint, rv1, rv2]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ## **5. Check for duplicates values**

# %%
duplicates = data.duplicated()
data[duplicates]
# Out:
# Empty DataFrame
# Columns: [date, Appliances, lights, T1, RH_1, T2, RH_2, T3, RH_3, T4, RH_4, T5, RH_5, T6, RH_6, T7, RH_7, T8, RH_8, T9, RH_9, T_out, Press_mm_hg, RH_out, Windspeed, Visibility, Tdewpoint, rv1, rv2]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ## **6. Explore the dataset basic statistics**

# %%
data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %% [markdown]
# ## STEP THREE
#
# 1. SPLITTING THE DATASET
#
# 2. MODEL SELECTION
#
# 3. MODEL TRAINING

# %% [markdown]
# ## **1. Splitting the data into train and test data**

# %%
# 'X' contain the feature columns, and 'y' is the target variable (Appliances energy usage).
X = data.drop(columns=['date','lights','Appliances'])  # Feature columns
y = data['Appliances']  # Target variable

# Split the data into a training set and a testing set (using 70% training and 30% testing).
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Hence, for information on the structure of the splitted data
print(f"The training data has {len(X_train)} rows")
print(f"The testing data has {len(X_test)} rows")
# Out:
# The training data has 13814 rows
# The testing data has 5921 rows

# %% [markdown]
# ## 2. Model Selection & Model Training Stage
# - This stage provides answer to the quiz code question

# %%
# Extracting the 'T2' (living room temperature) and 'T6' (outside temperature) columns from the dataset.
X = data[['T2']].values
y = data['T6'].values

# %%
# Create a Linear Regression model
my_model = LinearRegression()

# Train the model on your scaled training data
my_model.fit(X, y)

# Now you can make predictions
y_pred = my_model.predict(X)

#Calculate the RMSE
rmse = np.sqrt(mean_squared_error(y, y_pred))
rmse = round(rmse, 3)

#Print the reu
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 3.644

# %%
scaler=MinMaxScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)
y_pred = my_model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = model.predict(X_test_scaled)  # Make predictions using your model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Assuming you have a DataFrame 'X_train' containing multiple features
# 'y_train' is your target variable

# Select the desired feature (e.g., the first feature) by its column name
selected_feature = 'date','lights','Appliances' # Replace 'FeatureName' with the actual feature name

X_train_selected = X_train[[selected_feature]]

# Create and fit the Linear Regression model
model = LinearRegression()
model.fit(X_train_selected, y_train)

# Make predictions on the training data
y_pred_train = model.predict(X_train_selected)

# Calculate RMSE for the training set
rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))

# Print RMSE with three decimal places
print(f"RMSE for the training set: {rmse_train:.3f}")
